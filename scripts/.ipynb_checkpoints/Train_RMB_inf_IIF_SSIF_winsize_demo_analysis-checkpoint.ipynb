# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import math
import sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
import os
import subprocess as sp

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
np.random.seed(4)

from models import EarlyStopping, GRU
from utilities import get_NSE, MSE, get_colors, print_notes, inverse_transform_sp
from preprocess import load_data, SampleData

# %%
def get_gpu_memory():
    _output_to_list = lambda x: x.decode('ascii').split('\n')[:-1]
    ACCEPTABLE_AVAILABLE_MEMORY = 1024
    COMMAND = "nvidia-smi --query-gpu=memory.free --format=csv"
    memory_free_info = _output_to_list(sp.check_output(COMMAND.split()))[1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    return memory_free_values

if torch.cuda.is_available():
    device = torch.device("cuda")
if get_gpu_memory()[0] < 1500 :
    device = torch.device("cpu")
print(device)

# Get colors
colors = get_colors()
colors
# Out:
# cuda
# array(['deeppink', 'darkviolet', 'darkgray', 'darkblue', 'darkkhaki',
#        'deepskyblue', 'darkslategray', 'darkgreen', 'darkslategrey',
#        'darkseagreen', 'darkred', 'darkmagenta', 'darksalmon',
#        'darkorchid', 'darkorange', 'darkgoldenrod', 'darkturquoise',
#        'darkolivegreen', 'darkcyan', 'darkgrey', 'darkslateblue'],
#       dtype='<U14')

# %%
output_vars = ['SW_ENDmm']
run_task = 'Train_RMB_inf_IIF_SSIF_SW'
# output_vars = ['SNOmm']
# run_task = 'Train_RMB_inf_IIF_SSIF_SNO'
# output_vars = ['Q_pred_mm']
# run_task = 'Train_RMB_inf_IIF_SSIF_SF'

# %%
import pickle
sim_type = 'full_wsl'
rversion = 'hs32'

train_years = 160
res_dir = '../results/head_water_SWAT_1000_years/'


for output_vars, run_task in [(['SW_ENDmm'],'Train_RMB_inf_IIF_SSIF_SW'),
                              (['SNOmm'],'Train_RMB_inf_IIF_SSIF_SNO'),
                              (['Q_pred_mm'],'Train_RMB_inf_IIF_SSIF_SF')]:

    pred_test_itrs_data = []
    hiddens_test_itrs_data = []
    mean_rmse_data = []
    stdv_rmse_data = []
    mean_nse_data = []
    stdv_nse_data = []

    pred_test_itrs_data_SSIF = []
    hiddens_test_itrs_data_SSIF = []
    mean_rmse_data_SSIF = []
    stdv_rmse_data_SSIF = []
    mean_nse_data_SSIF = []
    stdv_nse_data_SSIF = []

    for n_steps in [14, 30, 90, 180, 366]:
        exp_dir = res_dir + '{}/rversion_{}_years_{}_winsize_{}/'.format(run_task, rversion, train_years, n_steps)
        if n_steps == 366:
            exp_dir = res_dir + '{}/rversion_{}_years_{}/'.format(run_task, rversion, train_years)

        #--------------------------------------------- load input data -----------------------------
        new_data_dir = '../data/1000_year_simulation/'
        if sim_type =='full_wsl':
            path = new_data_dir + 'head_water_SWAT_1000_years.csv'
        elif sim_type =='nosnow_nofrozen_wsl':
            path = new_data_dir + 'head_water_SWAT_1000_years_no_snow_no_frozen.csv'
        elif sim_type =='nosnow_wsl':
            path = new_data_dir + 'head_water_SWAT_1000_years_no_snow.csv'
        else:
            raise FileNotFoundError

        run_iter = 5
        max_iter = run_iter
        hidden_size = 32
        epochs = 500
        learning_rate = 0.01
        n_classes = len(output_vars)
        batch_size = 64
        input_size = 7
        dropout = 0
        nlayers=1
        patience = 50

        input_vars = ['Date', 'PRECIPmm', 'TMP_MXdgC', 'TMP_MNdgC', 'SOLARMJ/m2', 'WINDM/s', 'RHmd']
        assert(len(input_vars) == input_size)

        params = np.load(exp_dir + 'params_ss_{}.npy'.format(n_steps),allow_pickle=True).tolist()
        # print("The network hypermeters : ")
        # for k,v in params.items():
        #     if k != "notes":
        #         print(k,v)
        #     if k == "notes":
        #         print()
        #         print_notes(params['notes'][0])


        df = pd.read_csv(path)
        feat, label = load_data(df, output_vars, input_vars, input_size)

        # First 50% of data as the training set, middle 10% of data as the validation set, last 40% of data as the testing set.
        train_percentage = 0.5
        valid_percentage = 0.1
        test_percentage = 1 - (train_percentage + valid_percentage)

        # Split data
        T = feat.shape[0]
        train_len = int(T*train_percentage)
        valid_len = int(T*valid_percentage)
        test_len = T - train_len - valid_len
        print(train_len,valid_len,test_len)
        train_x = feat[:train_len].copy()
        train_y = label[:train_len].copy()
        valid_x = feat[train_len:train_len+valid_len].copy()
        valid_y = label[train_len:train_len+valid_len].copy()
        test_x = feat[train_len+valid_len:].copy()
        test_y = label[train_len+valid_len:].copy()

        # Normalize data
        scaler_x = StandardScaler()
        scaler_x.fit(train_x) 
        x_train = scaler_x.transform(train_x)
        x_valid = scaler_x.transform(valid_x)
        x_test = scaler_x.transform(test_x)
        scaler_y = StandardScaler()
        scaler_y.fit(train_y)
        y_train = scaler_y.transform(train_y)
        y_valid = scaler_y.transform(valid_y)
        y_test = scaler_y.transform(test_y)

        # Sample data
        ## Get indexes
        train_idx = np.arange(len(y_train))
        valid_idx = np.arange(len(y_valid))
        test_idx = np.arange(len(y_test))
        ## Set stride
        num_samples_train = 0
        shift_train = int(n_steps / 2)
        num_samples_valid = 0
        shift_valid = int(n_steps / 2)
        num_samples_test = 0
        shift_test = int(n_steps / 2)
        ## Get lists of indexes to sample data. 
        train_idx_arr = SampleData(train_idx,n_steps,shift_train,num_samples_train)
        num_train_samples = train_idx_arr.shape[0]
        valid_idx_arr = SampleData(valid_idx,n_steps,shift_valid,num_samples_valid)
        num_valid_samples = valid_idx_arr.shape[0]
        test_idx_arr = SampleData(test_idx,n_steps,shift_test,num_samples_test)
        num_test_samples = test_idx_arr.shape[0]
        ## Sample data
        x_train_sp_ = x_train[train_idx_arr,:]
        y_train_sp_ = y_train[train_idx_arr,:]
        m_train_sp_ = y_train_sp_.copy()
        m_train_sp_[:,:,:] = 1 # no masking
        x_valid_sp_ = x_valid[valid_idx_arr,:]
        y_valid_sp_ = y_valid[valid_idx_arr,:]
        m_valid_sp_ = y_valid_sp_.copy()
        m_valid_sp_[:,:,:] = 1 # no masking
        x_test_sp_ = x_test[test_idx_arr,:]
        y_test_sp_ = y_test[test_idx_arr,:]
        m_test_sp_ = y_test_sp_.copy()
        m_test_sp_[:,:,:] = 1 # no masking

        # Send data to the device
        x_train_sp = torch.from_numpy(x_train_sp_).type(torch.float32).to(device)
        y_train_sp = torch.from_numpy(y_train_sp_).type(torch.float32).to(device)
        m_train_sp = torch.from_numpy(m_train_sp_).type(torch.float32).to(device)

        x_valid_sp = torch.from_numpy(x_valid_sp_).type(torch.float32).to(device)
        y_valid_sp = torch.from_numpy(y_valid_sp_).type(torch.float32).to(device)
        m_valid_sp = torch.from_numpy(m_valid_sp_).type(torch.float32).to(device)

        x_test_sp = torch.from_numpy(x_test_sp_).type(torch.float32).to(device)
        y_test_sp = torch.from_numpy(y_test_sp_).type(torch.float32).to(device)
        m_test_sp = torch.from_numpy(m_test_sp_).type(torch.float32).to(device)

        # IIF Inference #####################################################
        print("IIF Inference ###")
        pred_test_itrs = []
        hiddens_test_itrs = []
        for run_iter in np.arange(max_iter):
            # print('Iteration {}'.format(run_iter))
            # Load the best validation model
            path_save = exp_dir+"run_iter_{}_best_model.sav".format(run_iter)
            checkpoint=torch.load(path_save)
            model_trained=GRU(input_size, hidden_size, nlayers, n_classes, dropout)
            model_trained.load_state_dict(checkpoint['model_state_dict'])
            model_trained.to(device)
            epoch = checkpoint['epoch']
            # print("Best epoch is {}".format(epoch))
            with torch.no_grad():
                model_trained.eval()
                hidden_head = model_trained.init_hidden(num_test_samples)
                pred_test,hiddens_test = model_trained(x_test_sp,hidden_head)
                loss_test = MSE(pred_test, y_test_sp, m_test_sp).cpu().numpy()
                pred_test = pred_test.cpu().numpy()
                hiddens_test = hiddens_test.cpu().numpy()

            # Transform the output back to the original scale.
            pred_test, y_test_ori = inverse_transform_sp(pred_test, y_test_sp.cpu().numpy(), scaler_y,n_classes)
            pred_test_itrs.append(pred_test)
            hiddens_test_itrs.append(hiddens_test)

        pred_test_itrs_data.append(pred_test_itrs)
        hiddens_test_itrs_data.append(hiddens_test_itrs)

        y_sp = np.squeeze(y_test_sp.cpu().numpy())
        m_sp = np.squeeze(m_test_sp.cpu().numpy())
        y_ori =  y_sp.reshape(-1,n_classes)
        y_ori = scaler_y.inverse_transform(y_ori).reshape(y_sp.shape)
        idx_arr = test_idx_arr

        with open(exp_dir + "pred_test_itrs.npy", 'wb') as f:
            np.save(f, pred_test_itrs)
        with open(exp_dir + "test_idx_arr.npy", 'wb') as f:
            np.save(f, test_idx_arr)

        rmses_test = []
        for pred_test in pred_test_itrs:
            rmses_test.append(np.sqrt(MSE(pred_test, y_ori, m_sp)))

        rmses_test = np.asarray(rmses_test).reshape(-1,1)
        print("------- Training window size : {} days".format(n_steps))
        print("Test RMSE Mean")
        print(np.round(rmses_test,4))
        print("Test RMSE Mean : {}".format(np.mean(rmses_test)))
        print("Test RMSE stdv : {}".format(np.std(rmses_test)))
        print()

        nses_test = []        
        for pred_test in pred_test_itrs:
            nses_test.append(get_NSE(y_ori, pred_test))

        nses_test = np.asarray(nses_test)
        print("Test NSE")
        print(np.round(nses_test,4))
        print("Test NSE Mean : {:.3f}".format(np.mean(nses_test)))
        print("Test NSE stdv : {:.3f}".format(np.std(nses_test)))

        mean_rmse_data.append([n_steps,np.mean(rmses_test)])
        stdv_rmse_data.append([n_steps,np.std(rmses_test)])
        mean_nse_data.append([n_steps,np.mean(rmses_test)])
        stdv_nse_data.append([n_steps,np.std(rmses_test)])
        print()

        # SSIF Inference #####################################################
        print("SSIF Inference ###")
        pred_test_itrs = []
        hiddens_test_itrs = []
        rmses_test_itrs = []

        for run_iter in np.arange(max_iter):
            # print('Iteration {}'.format(run_iter))
            # Load the best validation model
            path_save = exp_dir+"run_iter_{}_best_model.sav".format(run_iter)
            checkpoint=torch.load(path_save)
            model_trained=GRU(input_size, hidden_size, nlayers, n_classes, dropout)
            model_trained.load_state_dict(checkpoint['model_state_dict'])
            model_trained.to(device)
            epoch = checkpoint['epoch']
            # print("Best epoch is {}".format(epoch))

            with torch.no_grad():
                model_trained.eval()
                hidden_head = model_trained.init_hidden(1)
                X = torch.from_numpy(np.expand_dims(x_test,0)).type(torch.float32).to(device)
                pred_test,hiddens_test = model_trained(X,hidden_head)
                pred_test = pred_test.cpu().numpy().reshape(-1,1)
                hiddens_test = np.squeeze(hiddens_test.cpu().numpy())
                pred_test = scaler_y.inverse_transform(pred_test)
                loss_test = MSE(pred_test, test_y)
                rmses_test_itrs.append(np.sqrt(loss_test))
                # print("Epoch {} : epoch_loss_test RMSE loss {:.4f}".format(str(epoch), np.sqrt(loss_test)))
                # print()
            pred_test_itrs.append(pred_test)
            hiddens_test_itrs.append(hiddens_test)

        with open(exp_dir + "pred_test_agg_stateful_itrs.npy", 'wb') as f:
            np.save(f, pred_test_itrs)

        rmses_test_itrs = np.asarray(rmses_test_itrs)
        print("Test RMSE Mean")
        print(np.round(rmses_test_itrs,3))
        print("Test RMSE Mean : {:.3f}".format(np.mean(rmses_test_itrs)))
        print("Test RMSE stdv : {:.3f}".format(np.std(rmses_test_itrs)))  

        nses_test_itrs = []
        for pred_test in pred_test_itrs:
            nses_test_itrs.append(get_NSE(test_y, pred_test))

        nses_test_itrs = np.asarray(nses_test_itrs)
        print("Test NSE")
        print(np.round(nses_test_itrs,3))
        print("Test NSE Mean : {:.3f}".format(np.mean(nses_test_itrs)))
        print("Test NSE stdv : {:.3f}".format(np.std(nses_test_itrs)))

        pred_test_itrs_data_SSIF.append(pred_test_itrs)
        hiddens_test_itrs_data_SSIF.append(hiddens_test_itrs) 
        mean_rmse_data_SSIF.append([n_steps,np.mean(rmses_test_itrs)])
        stdv_rmse_data_SSIF.append([n_steps,np.std(rmses_test_itrs)])
        mean_nse_data_SSIF.append([n_steps,np.mean(nses_test_itrs)])
        stdv_nse_data_SSIF.append([n_steps,np.std(nses_test_itrs)])   

    exp_dir = res_dir + '{}/rversion_{}/'.format(run_task, rversion)

    import pdb; pdb.set_trace()
    results_data = {'pred_test_itrs_data':np.squeeze(pred_test_itrs_data),
                   'mean_rmse_data':np.squeeze(mean_rmse_data), 'stdv_rmse_data':stdv_rmse_data,
                   'mean_nse_data':np.squeeze(mean_nse_data), 'stdv_nse_data':stdv_nse_data}
    with open(exp_dir+'results_winsize.pickle', 'wb') as handle:
        pickle.dump(results_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

    results_data = {'pred_test_itrs_data':np.squeeze(pred_test_itrs_data_SSIF),
                   'mean_rmse_data':np.squeeze(mean_rmse_data_SSIF), 'stdv_rmse_data':stdv_rmse_data_SSIF,
                   'mean_nse_data':np.squeeze(mean_nse_data_SSIF), 'stdv_nse_data':stdv_nse_data_SSIF}
    with open(exp_dir+'results_winsize_SSIF.pickle', 'wb') as handle:
        pickle.dump(results_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

    mean_rmse_data = np.squeeze(mean_rmse_data)
    stdv_rmse_data = np.squeeze(stdv_rmse_data)
    mean_rmse_data_SSIF = np.squeeze(mean_rmse_data_SSIF)
    stdv_rmse_data_SSIF = np.squeeze(stdv_rmse_data_SSIF)

    fig = plt.figure()
    plt.errorbar(mean_rmse_data[:,0], mean_rmse_data[:,1], yerr=stdv_rmse_data[:,1], label='IIF')
    plt.errorbar(mean_rmse_data_SSIF[:,0], mean_rmse_data_SSIF[:,1], yerr=stdv_rmse_data_SSIF[:,1], label='SSIF')
    # plt.title('RMSE of models')
    plt.xlabel('RNN lengths')
    plt.ylabel('RMSE')
    plt.legend()
    plt.show()
# Out:
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 14 days
# Test RMSE Mean
# [[49.8472]
#  [49.8316]
#  [49.3738]
#  [49.5161]
#  [49.4474]]
# Test RMSE Mean : 49.60321843176871
# Test RMSE stdv : 0.19807190209898404
#
# Test NSE
# [0.1376 0.1382 0.1539 0.149  0.1514]
# Test NSE Mean : 0.146
# Test NSE stdv : 0.007
#
# SSIF Inference ###
# Test RMSE Mean
# [47.013 49.812 43.895 46.985 46.345]
# Test RMSE Mean : 46.810
# Test RMSE stdv : 1.887
# Test NSE
# [0.233 0.139 0.331 0.234 0.255]
# Test NSE Mean : 0.238
# Test NSE stdv : 0.061
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 30 days
# Test RMSE Mean
# [[48.1457]
#  [48.6432]
#  [48.5016]
#  [47.9818]
#  [48.1932]]
# Test RMSE Mean : 48.293075991320094
# Test RMSE stdv : 0.2427538806490499
#
# Test NSE
# [0.1955 0.1788 0.1836 0.201  0.1939]
# Test NSE Mean : 0.191
# Test NSE stdv : 0.008
#
# SSIF Inference ###
# Test RMSE Mean
# [42.769 41.117 44.307 43.975 43.954]
# Test RMSE Mean : 43.224
# Test RMSE stdv : 1.176
# Test NSE
# [0.365 0.413 0.319 0.329 0.33 ]
# Test NSE Mean : 0.351
# Test NSE stdv : 0.035
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 90 days
# Test RMSE Mean
# [[44.8097]
#  [44.6776]
#  [44.4402]
#  [44.9283]
#  [44.5374]]
# Test RMSE Mean : 44.67861659040052
# Test RMSE stdv : 0.17679895760139117
#
# Test NSE
# [0.303  0.3071 0.3145 0.2993 0.3115]
# Test NSE Mean : 0.307
# Test NSE stdv : 0.005
#
# SSIF Inference ###
# Test RMSE Mean
# [34.691 33.247 34.717 32.988 35.396]
# Test RMSE Mean : 34.208
# Test RMSE stdv : 0.929
# Test NSE
# [0.582 0.616 0.582 0.622 0.565]
# Test NSE Mean : 0.594
# Test NSE stdv : 0.022
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 180 days
# Test RMSE Mean
# [[41.8256]
#  [40.9573]
#  [40.7795]
#  [40.8113]
#  [41.2392]]
# Test RMSE Mean : 41.1226007252577
# Test RMSE stdv : 0.387237442135152
#
# Test NSE
# [0.3927 0.4177 0.4227 0.4218 0.4096]
# Test NSE Mean : 0.413
# Test NSE stdv : 0.011
#
# SSIF Inference ###
# Test RMSE Mean
# [32.863 29.597 25.6   27.323 28.387]
# Test RMSE Mean : 28.754
# Test RMSE stdv : 2.438
# Test NSE
# [0.625 0.696 0.773 0.741 0.72 ]
# Test NSE Mean : 0.711
# Test NSE stdv : 0.050
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 366 days
# Test RMSE Mean
# [[34.8412]
#  [35.0923]
#  [34.3838]
#  [35.2729]
#  [34.4375]]
# Test RMSE Mean : 34.80553790993049
# Test RMSE stdv : 0.35077871388616766
#
# Test NSE
# [0.5787 0.5726 0.5896 0.5681 0.5884]
# Test NSE Mean : 0.579
# Test NSE stdv : 0.008
#
# SSIF Inference ###
# Test RMSE Mean
# [23.874 24.856 21.023 25.783 22.939]
# Test RMSE Mean : 23.695
# Test RMSE stdv : 1.640
# Test NSE
# [0.802 0.786 0.847 0.769 0.817]
# Test NSE Mean : 0.804
# Test NSE stdv : 0.027
# /home/kumarv/xu000114/.conda/envs/pytorch/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 14 days
# Test RMSE Mean
# [[8.2365]
#  [8.2177]
#  [8.231 ]
#  [8.3997]
#  [8.1699]]
# Test RMSE Mean : 8.250944894394198
# Test RMSE stdv : 0.07798893907272592
#
# Test NSE
# [0.5118 0.514  0.5124 0.4922 0.5196]
# Test NSE Mean : 0.510
# Test NSE stdv : 0.009
#
# SSIF Inference ###
# Test RMSE Mean
# [6.193 9.121 6.859 7.958 7.728]
# Test RMSE Mean : 7.572
# Test RMSE stdv : 0.998
# Test NSE
# [0.724 0.401 0.661 0.544 0.57 ]
# Test NSE Mean : 0.580
# Test NSE stdv : 0.110
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 30 days
# Test RMSE Mean
# [[7.1228]
#  [7.169 ]
#  [7.2866]
#  [7.1246]
#  [7.1089]]
# Test RMSE Mean : 7.162382594440876
# Test RMSE stdv : 0.06533066489672348
#
# Test NSE
# [0.6348 0.6301 0.6178 0.6346 0.6362]
# Test NSE Mean : 0.631
# Test NSE stdv : 0.007
#
# SSIF Inference ###
# Test RMSE Mean
# [4.7   4.396 6.149 4.263 3.916]
# Test RMSE Mean : 4.685
# Test RMSE stdv : 0.774
# Test NSE
# [0.841 0.861 0.728 0.869 0.89 ]
# Test NSE Mean : 0.838
# Test NSE stdv : 0.057
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 90 days
# Test RMSE Mean
# [[5.0209]
#  [5.2002]
#  [5.0477]
#  [4.9813]
#  [4.9292]]
# Test RMSE Mean : 5.035840175260197
# Test RMSE stdv : 0.0913467845780143
#
# Test NSE
# [0.8184 0.8052 0.8165 0.8213 0.825 ]
# Test NSE Mean : 0.817
# Test NSE stdv : 0.007
#
# SSIF Inference ###
# Test RMSE Mean
# [3.188 2.983 3.161 3.111 3.209]
# Test RMSE Mean : 3.130
# Test RMSE stdv : 0.080
# Test NSE
# [0.927 0.936 0.928 0.93  0.926]
# Test NSE Mean : 0.929
# Test NSE stdv : 0.004
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 180 days
# Test RMSE Mean
# [[3.7032]
#  [3.9017]
#  [3.681 ]
#  [3.672 ]
#  [3.4944]]
# Test RMSE Mean : 3.6904518770487797
# Test RMSE stdv : 0.12934720238207761
#
# Test NSE
# [0.9012 0.8903 0.9024 0.9029 0.912 ]
# Test NSE Mean : 0.902
# Test NSE stdv : 0.007
#
# SSIF Inference ###
# Test RMSE Mean
# [2.34  2.681 2.433 2.489 2.254]
# Test RMSE Mean : 2.439
# Test RMSE stdv : 0.145
# Test NSE
# [0.961 0.948 0.957 0.955 0.963]
# Test NSE Mean : 0.957
# Test NSE stdv : 0.005
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 366 days
# Test RMSE Mean
# [[2.9855]
#  [3.3876]
#  [2.9938]
#  [3.1579]
#  [3.1659]]
# Test RMSE Mean : 3.1381350510261052
# Test RMSE stdv : 0.14664822356401216
#
# Test NSE
# [0.9359 0.9174 0.9355 0.9282 0.9279]
# Test NSE Mean : 0.929
# Test NSE stdv : 0.007
#
# SSIF Inference ###
# Test RMSE Mean
# [2.185 2.747 2.177 2.494 2.356]
# Test RMSE Mean : 2.392
# Test RMSE stdv : 0.213
# Test NSE
# [0.966 0.946 0.966 0.955 0.96 ]
# Test NSE Mean : 0.959
# Test NSE stdv : 0.008
# /home/kumarv/xu000114/.conda/envs/pytorch/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 14 days
# Test RMSE Mean
# [[1.354 ]
#  [1.3794]
#  [1.369 ]
#  [1.3685]
#  [1.3438]]
# Test RMSE Mean : 1.3629377963689644
# Test RMSE stdv : 0.012522513160734265
#
# Test NSE
# [0.7845 0.7764 0.7797 0.7799 0.7878]
# Test NSE Mean : 0.782
# Test NSE stdv : 0.004
#
# SSIF Inference ###
# Test RMSE Mean
# [1.544 1.563 1.453 1.716 1.462]
# Test RMSE Mean : 1.548
# Test RMSE stdv : 0.095
# Test NSE
# [0.72  0.713 0.752 0.654 0.749]
# Test NSE Mean : 0.717
# Test NSE stdv : 0.035
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 30 days
# Test RMSE Mean
# [[1.2126]
#  [1.1957]
#  [1.1998]
#  [1.1958]
#  [1.1883]]
# Test RMSE Mean : 1.1984389552833898
# Test RMSE stdv : 0.007974796557651919
#
# Test NSE
# [0.8271 0.8319 0.8307 0.8318 0.8339]
# Test NSE Mean : 0.831
# Test NSE stdv : 0.002
#
# SSIF Inference ###
# Test RMSE Mean
# [1.128 1.06  1.086 1.096 1.043]
# Test RMSE Mean : 1.082
# Test RMSE stdv : 0.030
# Test NSE
# [0.85  0.868 0.861 0.859 0.872]
# Test NSE Mean : 0.862
# Test NSE stdv : 0.008
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 90 days
# Test RMSE Mean
# [[1.0023]
#  [0.9634]
#  [0.9728]
#  [0.972 ]
#  [0.9677]]
# Test RMSE Mean : 0.9756419165087437
# Test RMSE stdv : 0.01374920129370804
#
# Test NSE
# [0.8819 0.8909 0.8887 0.8889 0.8899]
# Test NSE Mean : 0.888
# Test NSE stdv : 0.003
#
# SSIF Inference ###
# Test RMSE Mean
# [0.828 0.777 0.786 0.795 0.783]
# Test RMSE Mean : 0.794
# Test RMSE stdv : 0.018
# Test NSE
# [0.919 0.929 0.927 0.926 0.928]
# Test NSE Mean : 0.926
# Test NSE stdv : 0.003
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 180 days
# Test RMSE Mean
# [[0.858 ]
#  [0.8794]
#  [0.8424]
#  [0.8562]
#  [0.8561]]
# Test RMSE Mean : 0.8584202610744246
# Test RMSE stdv : 0.011912893924683978
#
# Test NSE
# [0.9134 0.9091 0.9166 0.9138 0.9138]
# Test NSE Mean : 0.913
# Test NSE stdv : 0.002
#
# SSIF Inference ###
# Test RMSE Mean
# [0.748 0.774 0.719 0.745 0.744]
# Test RMSE Mean : 0.746
# Test RMSE stdv : 0.017
# Test NSE
# [0.934 0.93  0.939 0.935 0.935]
# Test NSE Mean : 0.935
# Test NSE stdv : 0.003
# 182622 36524 146098
# 182622
# 36524
# 146098
# IIF Inference ###
# ------- Training window size : 366 days
# Test RMSE Mean
# [[0.7882]
#  [0.8205]
#  [0.7833]
#  [0.7681]
#  [0.7995]]
# Test RMSE Mean : 0.7919297773592975
# Test RMSE stdv : 0.017495005370086858
#
# Test NSE
# [0.927  0.9209 0.9279 0.9307 0.9249]
# Test NSE Mean : 0.926
# Test NSE stdv : 0.003
#
# SSIF Inference ###
# Test RMSE Mean
# [0.708 0.743 0.67  0.662 0.721]
# Test RMSE Mean : 0.701
# Test RMSE stdv : 0.031
# Test NSE
# [0.941 0.935 0.947 0.949 0.939]
# Test NSE Mean : 0.942
# Test NSE stdv : 0.005
# /home/kumarv/xu000114/.conda/envs/pytorch/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
